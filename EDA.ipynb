# %%
# %load_ext watermark
# %watermark -d -v -m -p pandas
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# 2017-05-08
#
# CPython 3.5.2
# IPython 5.1.0
#
# pandas 0.18.1
#
# compiler   : GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)
# system     : Darwin
# release    : 16.5.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 4
# interpreter: 64bit

# %%
import pandas as pd
import glob

# %% [markdown]
# ## Read Microseismicity events

# %%
path ='../data/microseismic_and_blasting_2009_2016/' # use your path
allEvents = glob.glob(path + "/*events.csv")
allBlasts = glob.glob(path + "/*blasts.csv")

frameEvents = pd.DataFrame()
list_ = []
for file_ in allEvents:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frameEvents = pd.concat(list_)

frameBlasts = pd.DataFrame()
list_ = []
for file in allBlasts:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frameBlasts = pd.concat(list_)

frames = [frameEvents,frameBlasts]
frame = pd.concat(frames)

# %%
frame['Type'].value_counts()
# Out:
# n    1185824
# e     779955
# u        425
# a         15
# Name: Type, dtype: int64

# %%
ls ../data/microseismic_and_blasting_2009_2016/
# Out:
# ../data/microseismic and blasting 2009-2016/2016events.csv*

# %%
frame.head(100)
# Out:
#    Date(y/m/d) Time(H:M:S)  MilliSec Type  Northing   Easting    Depth  \
# 0   2009/01/28    14:58:30       154    n  10151.63  10346.47  3098.37
# 1   2009/01/28    14:59:56       872    e  10127.32  10308.23  2620.29
# 2   2009/01/28    15:00:31       904    n  10144.80  10330.61  3103.87
# 3   2009/01/28    15:01:29       443    e  10008.00  10236.90  3082.62
# 4   2009/01/28    15:11:21       191    e  10006.04  10234.48  3082.73
# 5   2009/01/28    15:12:10       670    n  10132.89  10343.98  3100.33
# 6   2009/01/28    22:34:02       245    e   9974.08  10144.34  3098.28
# 7   2009/01/28    22:46:24       380    e  10156.98   9957.34  3041.54
# 8   2009/01/28    22:55:05       356    e  10148.50   9958.03  3059.75
# 9   2009/01/28    23:06:25       166    e  10146.10   9957.69  3058.05
# 10  2009/01/29    00:02:01       657    e  10158.69   9955.60  3054.40
# 11  2009/01/29    01:14:18        24    e  10273.37  10327.30  3030.34
# ...
